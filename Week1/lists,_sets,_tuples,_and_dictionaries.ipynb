# %% [markdown]
# <a href="https://colab.research.google.com/github/EnjamooriTejashwini/NASSCOM/blob/main/Week1/lists%2C_sets%2C_tuples%2C_and_dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = ['apple', 'banana', 'cherry', 'apple']
print("Original list:", fruits)

# Accessing elements by index
print("First fruit:", fruits[0])
# Out:
# Original list: ['apple', 'banana', 'cherry', 'apple']
# First fruit: apple

# %%
# Adding an item
fruits.append('orange')
print("After appending:", fruits)
# Out:
# After appending: ['apple', 'banana', 'cherry', 'apple', 'orange']

# %%
# Removing an item
fruits.remove('banana')
print("After removing banana:", fruits)

# List length
print("Number of fruits:", len(fruits))
# Out:
# After removing banana: ['apple', 'cherry', 'apple', 'orange']
# Number of fruits: 4

# %%
dimensions = (10, 20, 30)
print("Tuple:", dimensions)
# Out:
# Tuple: (10, 20, 30)

# %%
# Accessing elements
print("Second element:", dimensions[1])
# Out:
# Second element: 20

# %%
unique_numbers = {1, 2, 3, 2, 1}
print("Set (no duplicates):", unique_numbers)
# Out:
# Set (no duplicates): {1, 2, 3}

# %%
# Adding elements
unique_numbers.add(4)
print("After adding 4:", unique_numbers)
# Out:
# After adding 4: {1, 2, 3, 4}

# %%
# Removing elements
unique_numbers.remove(2)
print("After removing 2:", unique_numbers)
# Out:
# After removing 2: {1, 3, 4}

# %%
# Set operations
set_a = {1, 2, 3}
set_b = {3, 4, 5}
print("Union:", set_a | set_b)
print("Intersection:", set_a & set_b)
print("Difference (A - B):", set_a - set_b)
# Out:
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference (A - B): {1, 2}

# %%
student = {
    'name': 'Tejashwini',
    'age': 21,
    'course': 'Python'
}
print("Dictionary:", student)
# Out:
# Dictionary: {'name': 'Tejashwini', 'age': 21, 'course': 'Python'}

# %%
# Access value by key
print("Student name:", student['name'])
# Out:
# Student name: Tejashwini

# %%
# Add or update value
student['grade'] = 'A'
print("After adding grade:", student)

# Remove a key
del student['age']
print("After deleting age:", student)

# Loop through dictionary
for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# After adding grade: {'name': 'Tejashwini', 'age': 21, 'course': 'Python', 'grade': 'A'}
# After deleting age: {'name': 'Tejashwini', 'course': 'Python', 'grade': 'A'}
# name: Tejashwini
# course: Python
# grade: A

# %%
# Bonus: Dictionary from two lists using zip()
keys = ['id', 'name', 'marks']
values = [101, 'John', 88]
student_info = dict(zip(keys, values))
print("Student Info from zip:", student_info)
# Out:
# Student Info from zip: {'id': 101, 'name': 'John', 'marks': 88}
