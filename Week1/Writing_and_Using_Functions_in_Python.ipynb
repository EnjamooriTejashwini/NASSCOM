# %% [markdown]
# <a href="https://colab.research.google.com/github/EnjamooriTejashwini/NASSCOM/blob/main/Week1/Writing_and_Using_Functions_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A function is a block of code that performs a task and can be reused.

def greet():
    print("Hello! Welcome to Python Functions.")

# Calling the function
greet()
# Out:
# Hello! Welcome to Python Functions.

# %%
def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Teju")
greet_user("Netha")
# Out:
# Hello, Teju!
# Hello, Netha!

# %%
def greet_user(name="Guest"):
    print(f"Welcome, {name}!")

greet_user()         # Uses default
greet_user("Pranavi")   # Overrides default
# Out:
# Welcome, Guest!
# Welcome, Pranavi!

# %%
def print_names(*names):
    print("Names passed:", names)
    for name in names:
        print("Hello", name)

print_names("Teju", "bob", "Charmi")
# Out:
# Names passed: ('Teju', 'bob', 'Charmi')
# Hello Teju
# Hello bob
# Hello Charmi

# %%
# 🔹 6. USING **kwargs (VARIABLE NUMBER OF KEYWORD ARGUMENTS)

# **kwargs lets you pass any number of keyword arguments as a dictionary

def print_info(**info):
    print("User Info:")
    for key, value in info.items():
        print(f"{key} = {value}")

print_info(name="Alice", age=25, city="Delhi")
# Out:
# User Info:
# name = Alice
# age = 25
# city = Delhi

# %%
def show_details(*args, **kwargs):
    print("Args:", args)
    print("Kwargs:", kwargs)

show_details(1, 2, 3, name="Ravi", city="Mumbai")
# Out:
# Args: (1, 2, 3)
# Kwargs: {'name': 'Ravi', 'city': 'Mumbai'}

# %%
def multiply(a, b):
    return a * b

def square(n):
    return multiply(n, n)

print("Square of 4:", square(4))
# Out:
# Square of 4: 16
